# %% [markdown]
# <a href="https://colab.research.google.com/github/elmago07/AI-ML-Learnings/blob/main/pandas_learnings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
######Tow data structures in pandas:series and DataFrame######

# %%
import pandas as pd
###creating a series from a list###
data = [1,2,3,4,5]
series = pd.Series(data)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
####Data FRame###

data = {'Team': ['Redbull', 'Ferrai', 'McLaren'],
        'Driver': ['Max Verstappen', 'Hamilton', 'Lando Norris']}
df = pd.DataFrame(data)
print(df)
# Out:
#       Team          Driver
# 0  Redbull  Max Verstappen
# 1   Ferrai        Hamilton
# 2  McLaren    Lando Norris

# %%
data = {'Team': ['Redbull', 'Ferrai', 'McLaren'],
        'Driver': ['Max Verstappen', 'Hamilton', 'Lando Norris'],
        'Tyre': ['hard', 'soft', 'soft'],
        'Power_Unit': ['Honda', 'Ferrari', 'Mercedes']}
df = pd.DataFrame(data)
df
# Out:
#       Team          Driver  Tyre Power_Unit
# 0  Redbull  Max Verstappen  hard      Honda
# 1   Ferrai        Hamilton  soft    Ferrari
# 2  McLaren    Lando Norris  soft   Mercedes

# %%
data = {'Team': ['Redbull', 'Ferrai', 'McLaren'],
        'Driver': ['Max Verstappen', 'Hamilton', 'Lando Norris'],
        'Tyre': ['hard', 'soft', 'soft'],
        'Power_Unit': ['Honda', 'Ferrari', 'Mercedes']}
df = pd.DataFrame(data)
print(df.size)
print(df.ndim)
print(df.shape)
# Out:
# 12
# 2
# (3, 4)

# %%
import pandas as pd
data = {'Team': ['Redbull', 'Ferrai', 'McLaren'],
        'Driver': ['Max Verstappen', 'Hamilton', 'Lando Norris'],
        'Tyre': ['hard', 'soft', 'soft'],
        'Power_Unit': ['Honda', 'Ferrari', 'Mercedes']}
df = pd.DataFrame(data)
print(df.index)
print(df.columns)
print(df.values)
print(df.axes)
print(df.dtypes)
# Out:
# RangeIndex(start=0, stop=3, step=1)
# Index(['Team', 'Driver', 'Tyre', 'Power_Unit'], dtype='object')
# [['Redbull' 'Max Verstappen' 'hard' 'Honda']
#  ['Ferrai' 'Hamilton' 'soft' 'Ferrari']
#  ['McLaren' 'Lando Norris' 'soft' 'Mercedes']]
# [RangeIndex(start=0, stop=3, step=1), Index(['Team', 'Driver', 'Tyre', 'Power_Unit'], dtype='object')]
# Team          object
# Driver        object
# Tyre          object
# Power_Unit    object
# dtype: object

# %%
import pandas as pd
data = {'Team': ['Redbull', 'Ferrai', 'McLaren'],
        'Driver': ['Max Verstappen', 'Hamilton', 'Lando Norris'],
        'Tyre': ['hard', 'soft', 'soft'],
        'Power_Unit': ['Honda', 'Ferrari', 'Mercedes']}
df = pd.DataFrame(data)
df.info() #gives the entire data of data frame instead of calling one one method everyttime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Team        3 non-null      object
#  1   Driver      3 non-null      object
#  2   Tyre        3 non-null      object
#  3   Power_Unit  3 non-null      object
# dtypes: object(4)
# memory usage: 228.0+ bytes

# %%
import pandas as pd
data = {'Team': ['Redbull', 'Ferrai', 'McLaren'],
        'Driver': ['Max Verstappen', 'Hamilton', 'Lando Norris'],
        'Tyre': ['hard', 'soft', 'soft'],
        'Power_Unit': ['Honda', 'Ferrari', 'Mercedes']}
df = pd.DataFrame(data)
df.describe() #gives basic statics of data
# Out:
#            Team          Driver  Tyre Power_Unit
# count         3               3     3          3
# unique        3               3     2          3
# top     Redbull  Max Verstappen  soft      Honda
# freq          1               1     2          1

# %%
import pandas as pd
data = {'Team': ['Redbull', 'Ferrai', 'McLaren'],
        'Driver': ['Max Verstappen', 'Hamilton', 'Lando Norris'],
        'Tyre': ['hard', 'soft', 'soft'],
        'Power_Unit': ['Honda', 'Ferrari', 'Mercedes']}
df = pd.DataFrame(data)
df.memory_usage() #gives memeory usage of each column
# Out:
# Index         132
# Team           24
# Driver         24
# Tyre           24
# Power_Unit     24
# dtype: int64

# %%
# Accessing data in data frame
import pandas as pd
data = {'Team': ['Redbull', 'Ferrai', 'McLaren'],
        'Driver': ['Max Verstappen', 'Hamilton', 'Lando Norris'],
        'Tyre': ['hard', 'soft', 'soft'],
        'Power_Unit': ['Honda', 'Ferrari', 'Mercedes']}
df = pd.DataFrame(data)
#df.Team
df.Driver
# Out:
# 0    Max Verstappen
# 1          Hamilton
# 2      Lando Norris
# Name: Driver, dtype: object

# %%
### Acessing rows using iloc and loc
import pandas as pd
data = {'Team': ['Redbull', 'Ferrai', 'McLaren'],
        'Driver': ['Max Verstappen', 'Hamilton', 'Lando Norris'],
        'Tyre': ['hard', 'soft', 'soft'],
        'Power_Unit': ['Honda', 'Ferrari', 'Mercedes']}
df = pd.DataFrame(data)
print(df)
df.iloc[0:2] #Access row by position using iloc
# Out:
#       Team          Driver  Tyre Power_Unit
# 0  Redbull  Max Verstappen  hard      Honda
# 1   Ferrai        Hamilton  soft    Ferrari
# 2  McLaren    Lando Norris  soft   Mercedes
#       Team          Driver  Tyre Power_Unit
# 0  Redbull  Max Verstappen  hard      Honda
# 1   Ferrai        Hamilton  soft    Ferrari

# %%
### Acessing rows using iloc and loc
import pandas as pd
data = {'Team': ['Redbull', 'Ferrai', 'McLaren'],
        'Driver': ['Max Verstappen', 'Hamilton', 'Lando Norris'],
        'Tyre': ['hard', 'soft', 'soft'],
        'Power_Unit': ['Honda', 'Ferrari', 'Mercedes']}
df = pd.DataFrame(data)
print(df)
df.loc[0:2] ##access row by label using loc
# Out:
#       Team          Driver  Tyre Power_Unit
# 0  Redbull  Max Verstappen  hard      Honda
# 1   Ferrai        Hamilton  soft    Ferrari
# 2  McLaren    Lando Norris  soft   Mercedes
#       Team          Driver  Tyre Power_Unit
# 0  Redbull  Max Verstappen  hard      Honda
# 1   Ferrai        Hamilton  soft    Ferrari
# 2  McLaren    Lando Norris  soft   Mercedes

# %%
###Importing & Exploring a DataSet
import pandas as pd
df = pd.read_csv('worldbank_indicators.csv')
df
# Out:
#      country_code  year  remittances_received_usd  remittances_paid_usd  \
# 0              1A  2010              3.778065e+10          5.423934e+10
# 1              1A  2011              3.894486e+10          6.766183e+10
# 2              1A  2012              4.593362e+10          7.449443e+10
# 3              1A  2013              4.722886e+10          8.559665e+10
# 4              1A  2014              5.312215e+10          8.700395e+10
# ...           ...   ...                       ...                   ...
# 3705           ZW  2019              1.417012e+09          1.348057e+07
# 3706           ZW  2020              1.832039e+09          2.170709e+07
# 3707           ZW  2021              2.573627e+09          2.560172e+07
# 3708           ZW  2022              3.085043e+09          2.340965e+07
# 3709           ZW  2023              3.301268e+09          3.327118e+07
#
#       remittances_pct_gdp       gdp_usd  gdp_per_capita_usd  gdp_growth_pct  \
# ...

# %%
df.head() #prints first 5 rows
# Out:
#   country_code  year  remittances_received_usd  remittances_paid_usd  \
# 0           1A  2010              3.778065e+10          5.423934e+10
# 1           1A  2011              3.894486e+10          6.766183e+10
# 2           1A  2012              4.593362e+10          7.449443e+10
# 3           1A  2013              4.722886e+10          8.559665e+10
# 4           1A  2014              5.312215e+10          8.700395e+10
#
#    remittances_pct_gdp       gdp_usd  gdp_per_capita_usd  gdp_growth_pct  \
# 0             2.332815  2.161398e+12         5944.952173        4.840642
# 1             1.900776  2.573068e+12         6915.827681        3.853204
# 2             2.048791  2.813568e+12         7384.106828        5.493754
# 3             2.026886  2.883690e+12         7376.028296        2.647321
# 4             2.226287  2.937036e+12         7338.350927        2.659752
#
#    gni_per_capita_usd  inflation_cpi_pct  ...  mobile_money_accounts_pct  \
# ...

# %%
df.tail() #prints last 5 rows
# Out:
#      country_code  year  remittances_received_usd  remittances_paid_usd  \
# 3705           ZW  2019              1.417012e+09          1.348057e+07
# 3706           ZW  2020              1.832039e+09          2.170709e+07
# 3707           ZW  2021              2.573627e+09          2.560172e+07
# 3708           ZW  2022              3.085043e+09          2.340965e+07
# 3709           ZW  2023              3.301268e+09          3.327118e+07
#
#       remittances_pct_gdp       gdp_usd  gdp_per_capita_usd  gdp_growth_pct  \
# 3705             4.247931  3.335770e+10         2184.329239       -6.332450
# 3706             5.728644  3.198033e+10         2059.674454       -7.816951
# 3707             6.233403  4.128767e+10         2613.605421        8.468017
# 3708             7.569254  4.075756e+10         2536.400502        6.139263
# 3709             9.202966  3.587178e+10         2195.224921        5.350869
#
# ...

# %%
df.sample(5) #prints randomly 5 rows
# Out:
#      country_code  year  remittances_received_usd  remittances_paid_usd  \
# 1780           MA  2012              6.507905e+09          6.415293e+07
# 780            DK  2020              1.332177e+09          3.402495e+09
# 2947           TJ  2017              2.237179e+09          2.155523e+08
# 39             4E  2021              8.334138e+10          4.373943e+10
# 2287           PG  2015              3.944548e+06          2.806513e+08
#
#       remittances_pct_gdp       gdp_usd  gdp_per_capita_usd  gdp_growth_pct  \
# 1780             6.085715  1.069374e+11         3164.177246        3.062344
# 780              0.374595  3.556310e+11        60985.488560       -1.780106
# 2947            29.684972  7.536403e+09          829.457148        7.100000
# 39               0.401228  2.123143e+13         9974.578297        7.719796
# 2287             0.018158  2.172344e+10         2484.596340        6.578356
#
# ...

# %%
df.sample(10) #prints randomly 5 rows
# Out:
#      country_code  year  remittances_received_usd  remittances_paid_usd  \
# 2013           MV  2021              4.882675e+06          4.964661e+08
# 2137           NI  2019              1.686400e+09          1.600000e+06
# 2292           PG  2020              2.297151e+06          3.333814e+07
# 2969           TM  2011                       NaN          0.000000e+00
# 3516           XU  2012              8.748376e+09          5.821753e+10
# 799            DO  2011              4.240700e+09          5.655000e+08
# 2686           SN  2022              2.910590e+09          2.687177e+08
# 3027           TT  2013              1.451296e+08          2.159386e+08
# 3435           XM  2015              1.045835e+10          3.228450e+09
# 563            CG  2013              7.205715e+07          5.696704e+07
#
#       remittances_pct_gdp       gdp_usd  gdp_per_capita_usd  gdp_growth_pct  \
# 2013             0.092960  5.252457e+09        10176.143883       37.507870
# ...

# %%
df.info() #basic info of DataSet
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3710 entries, 0 to 3709
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country_code                 3696 non-null   object
#  1   year                         3710 non-null   int64
#  2   remittances_received_usd     3164 non-null   float64
#  3   remittances_paid_usd         3500 non-null   float64
#  4   remittances_pct_gdp          3149 non-null   float64
#  5   gdp_usd                      3624 non-null   float64
#  6   gdp_per_capita_usd           3624 non-null   float64
#  7   gdp_growth_pct               3604 non-null   float64
#  8   gni_per_capita_usd           3475 non-null   float64
#  9   inflation_cpi_pct            2617 non-null   float64
#  10  unemployment_pct             3286 non-null   float64
#  11  current_account_pct_gdp      2582 non-null   float64
# ...

# %%
df.describe() #gives stats summary
# Out:
#               year  remittances_received_usd  remittances_paid_usd  \
# count  3710.000000              3.164000e+03          3.500000e+03
# mean   2016.500000              2.755877e+10          1.254100e+10
# std       4.031672              7.774928e+10          4.576537e+10
# min    2010.000000              2.047511e+05          0.000000e+00
# 25%    2013.000000              2.314667e+08          4.787312e+07
# 50%    2016.500000              1.505247e+09          3.046175e+08
# 75%    2020.000000              9.550002e+09          4.821439e+09
# max    2023.000000              7.994185e+11          5.946499e+11
#
#        remittances_pct_gdp       gdp_usd  gdp_per_capita_usd  gdp_growth_pct  \
# count          3149.000000  3.624000e+03         3624.000000     3604.000000
# mean              4.412568  2.665748e+12        17151.593386        2.958571
# std               6.139164  9.200446e+12        25766.605724        5.820896
# ...

# %%
df
# Out:
#      country_code  year  remittances_received_usd  remittances_paid_usd  \
# 0              1A  2010              3.778065e+10          5.423934e+10
# 1              1A  2011              3.894486e+10          6.766183e+10
# 2              1A  2012              4.593362e+10          7.449443e+10
# 3              1A  2013              4.722886e+10          8.559665e+10
# 4              1A  2014              5.312215e+10          8.700395e+10
# ...           ...   ...                       ...                   ...
# 3705           ZW  2019              1.417012e+09          1.348057e+07
# 3706           ZW  2020              1.832039e+09          2.170709e+07
# 3707           ZW  2021              2.573627e+09          2.560172e+07
# 3708           ZW  2022              3.085043e+09          2.340965e+07
# 3709           ZW  2023              3.301268e+09          3.327118e+07
#
#       remittances_pct_gdp       gdp_usd  gdp_per_capita_usd  gdp_growth_pct  \
# ...

# %%
#Acessing a column index
df_indexed = df.set_index('country_code')
print(" *** DataFrame with country_code as index***:\n", df_indexed)
# Out:
#  *** DataFrame with country_code as index***:
#                year  remittances_received_usd  remittances_paid_usd  \
# country_code
# 1A            2010              3.778065e+10          5.423934e+10
# 1A            2011              3.894486e+10          6.766183e+10
# 1A            2012              4.593362e+10          7.449443e+10
# 1A            2013              4.722886e+10          8.559665e+10
# 1A            2014              5.312215e+10          8.700395e+10
# ...            ...                       ...                   ...
# ZW            2019              1.417012e+09          1.348057e+07
# ZW            2020              1.832039e+09          2.170709e+07
# ZW            2021              2.573627e+09          2.560172e+07
# ZW            2022              3.085043e+09          2.340965e+07
# ZW            2023              3.301268e+09          3.327118e+07
#
#               remittances_pct_gdp       gdp_usd  gdp_per_capita_usd  \
# country_code
# ...

# %%
###Access a row using index###
print("\n*** Row for index 1A ***:\n", df_indexed.loc['1A'])
# Out:
# *** Row for index 1A ***:
#                year  remittances_received_usd  remittances_paid_usd  \
# country_code
# 1A            2010              3.778065e+10          5.423934e+10
# 1A            2011              3.894486e+10          6.766183e+10
# 1A            2012              4.593362e+10          7.449443e+10
# 1A            2013              4.722886e+10          8.559665e+10
# 1A            2014              5.312215e+10          8.700395e+10
# 1A            2015              4.932802e+10          8.661684e+10
# 1A            2016              4.865741e+10          8.470168e+10
# 1A            2017              5.168558e+10          8.195513e+10
# 1A            2018              5.273131e+10          8.093177e+10
# 1A            2019              5.507635e+10          8.159893e+10
# 1A            2020              5.758399e+10          7.926412e+10
# 1A            2021              6.667699e+10          8.598752e+10
# ...
